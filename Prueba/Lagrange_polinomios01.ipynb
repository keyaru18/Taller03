# %% [markdown]
# # Ejercicio 1
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import lagrange

# Datos originales
x_data = np.array([0, 30, 60, 90])
y_data = np.array([0, 0.5, np.sqrt(3)/2, 1])

# Calcular el polinomio de Lagrange
poly = lagrange(x_data, y_data)

# Crear rango para la gráfica
x_plot = np.linspace(-10, 100, 500)
y_plot = poly(x_plot)

# Configuración de la gráfica
plt.figure(figsize=(14, 8))
plt.title('Interpolación de Lagrange con Desarrollo Matemático', fontsize=16)

# Graficar los polinomios base individuales
colors = ['red', 'green', 'blue', 'purple']
for i in range(4):
    # Crear polinomio base para cada punto
    base_poly = lagrange(x_data, np.eye(4)[i])
    plt.plot(x_plot, base_poly(x_plot), '--', color=colors[i], alpha=0.5, 
             label=f'$L_{i}(x)$ (Base para punto {x_data[i]}, {y_data[i]:.2f})')

# Graficar el polinomio final
plt.plot(x_plot, y_plot, 'k-', linewidth=3, label='Polinomio de Lagrange $P(x)$')

# Graficar puntos originales
plt.plot(x_data, y_data, 'ro', markersize=8, label='Puntos dados')

# Mostrar el polinomio en el gráfico
polynomial_text = (f"$P(x) = {poly.coeffs[0]:.5f}x^3 + {poly.coeffs[1]:.5f}x^2 + "
                  f"{poly.coeffs[2]:.5f}x + {poly.coeffs[3]:.5f}$")
plt.text(0.02, 0.98, polynomial_text, transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.8))

# Configuraciones adicionales
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.xlabel('x', fontsize=14)
plt.ylabel('y', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)
plt.xlim(-10, 100)
plt.ylim(-0.5, 1.5)

# Mostrar tabla con los cálculos
col_labels = ['Punto', 'x_i', 'y_i', 'Polinomio Base L_i(x)']
cell_text = [
    ['0', '0', '0', '$\\frac{(x-30)(x-60)(x-90)}{-162000}$'],
    ['1', '30', '0.5', '$\\frac{x(x-60)(x-90)}{54000}$'],
    ['2', '60', '$\\frac{\\sqrt{3}}{2}$', '$\\frac{x(x-30)(x-90)}{-54000}$'],
    ['3', '90', '1', '$\\frac{x(x-30)(x-60)}{162000}$']
]

plt.table(cellText=cell_text, colLabels=col_labels,
          loc='bottom', bbox=[0.1, -0.5, 0.8, 0.4])

plt.tight_layout()
plt.subplots_adjust(bottom=0.3)
plt.show()
